# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import Binarizer ,LabelEncoder
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import mean_squared_error,accuracy_score,mean_squared_log_error,r2_score

# %% [markdown]
# # Model on Train Data

# %%
#loading train data
Train_df=pd.read_csv('../Data/Train.csv')

# %%
Train_df.head()
# Out:
#       ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0  12554      current      M   35          708     24893.00       378.00
# 1  17645      current      M   35          123     18941.62       966.00
# 2   7604      current      M   55          802      5678.87      2724.00
# 3   1590      current      F   29          867     30489.50      1236.00
# 4  16556      current      M   34          802      7441.40      6906.04
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  ...  debit_count_may  \
# 0     10288.00     29664.00     16291.40  ...               40
# 1     20672.00       287.00      4217.00  ...               78
# 2      1964.50      3933.11     23956.25  ...               82
# 3     12609.88      9138.14     17521.00  ...               38
# 4      4364.00      1939.00      2121.00  ...               50
#
#    max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                24563.0          30051.32            12761.0
# 1                23948.0          42119.05            76206.0
# 2                10752.0          58373.25            75283.0
# 3                12607.0          69851.51            68708.0
# 4                25213.0          10071.00            80140.0
#
#    credit_count_jun  debit_count_jun  max_credit_amount_jun  loan_enq  \
# 0                 2               65                50836.0         Y
# 1                21               63                23226.0         Y
# 2                 7                1                27036.0         Y
# 3                21               83                43037.0         Y
# 4                 8               32                32044.0         Y
#
#    emi_active  cc_cons
# 0     1674.09    20014
# 1    13043.34    10173
# 2    25375.27    16095
# 3     3544.33     7707
# 4    12780.44    96408
#
# [5 rows x 44 columns]

# %%
# Dropping unneccessary columns
Train_df=Train_df.drop(['ID','personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed','loan_enq'],axis=1)

# %%
# coverting Categorical data to int

Train_df['account_type']=pd.get_dummies(Train_df['account_type'])

Train_df['gender']=pd.get_dummies(Train_df['gender'])

# %%
# Outliers Function to check outliers in dataframe

def check_outliers(df):
    col = list(df)
    outliers = pd.DataFrame(columns=['columns','Outliers'])
    
    for column in col:
        if column in df.select_dtypes(include=np.number).columns:
            q1 = df[column].quantile(0.25) 
            q3 = df[column].quantile(0.75)
            below = q1 - (1.5*q3 - q1)
            above = q3 + (1.5*q3 - q1)
            outliers = outliers.append({'columns':column,'Outliers':df.loc[(df[column] < below) | (df[column] > above)].shape[0]},ignore_index=True)
    return outliers

# %%
check_outliers(Train_df)
# Out:
#                   columns Outliers
# 0            account_type     2273
# 1                  gender     2055
# 2                     age      534
# 3             region_code        0
# 4             cc_cons_apr     1131
# 5             dc_cons_apr     1146
# 6             cc_cons_may     1113
# 7             dc_cons_may     1184
# 8             cc_cons_jun     1096
# 9             dc_cons_jun     1259
# 10           cc_count_apr      840
# 11           cc_count_may      296
# 12           cc_count_jun       49
# 13           dc_count_apr      231
# 14           dc_count_may     1233
# 15           dc_count_jun        0
# 16               card_lim       25
# 17           investment_1     2115
# 18           investment_2     1233
# 19           investment_3     1554
# 20           investment_4     1004
# 21       debit_amount_apr     1086
# 22      credit_amount_apr     1091
# 23        debit_count_apr      231
# 24       credit_count_apr       58
# 25  max_credit_amount_apr     1146
# 26       debit_amount_may     1103
# 27      credit_amount_may     1027
# 28       credit_count_may     2655
# 29        debit_count_may      617
# 30  max_credit_amount_may     1152
# 31       debit_amount_jun      999
# 32      credit_amount_jun     1073
# 33       credit_count_jun     1810
# 34        debit_count_jun        0
# 35  max_credit_amount_jun     1173
# 36             emi_active     1366
# 37                cc_cons     3113

# %%
# Dfine independent and target varible 
X= Train_df.iloc[:,:-1]

y= Train_df.cc_cons

# %%
#log Transformation to normilize the value of target variable
y = np.log1p(y)

# %%
# seprate the num columns and cat data columns
X_cols = X.columns
num_cols = X.select_dtypes(exclude=['object','category']).columns
cat_cols = [i for i in X_cols if i not in X[num_cols].columns]
for i in cat_cols:
    X[i] = X[i].astype('category')

# %%
#function for removing outliers
def removing_outliers(dataframe):
    cols = list(dataframe)
    for col in cols:
        if col in dataframe.select_dtypes(include=np.number).columns:
            dataframe[col] = winsorize(dataframe[col], limits=[0.1, 0.1],inclusive=(True, True))
    
    return dataframe

# %%
X[num_cols] = removing_outliers(X[num_cols])

check_outliers(X)
# Out:
#                   columns Outliers
# 0            account_type     2273
# 1                  gender     2055
# 2                     age        0
# 3             region_code        0
# 4             cc_cons_apr        0
# 5             dc_cons_apr        0
# 6             cc_cons_may        0
# 7             dc_cons_may        0
# 8             cc_cons_jun        0
# 9             dc_cons_jun        0
# 10           cc_count_apr        0
# 11           cc_count_may        0
# 12           cc_count_jun        0
# 13           dc_count_apr        0
# 14           dc_count_may        0
# 15           dc_count_jun        0
# 16               card_lim        0
# 17           investment_1     2115
# 18           investment_2        0
# 19           investment_3     1554
# 20           investment_4        0
# 21       debit_amount_apr        0
# 22      credit_amount_apr        0
# 23        debit_count_apr        0
# 24       credit_count_apr        0
# 25  max_credit_amount_apr        0
# 26       debit_amount_may        0
# 27      credit_amount_may        0
# 28       credit_count_may     2655
# 29        debit_count_may        0
# 30  max_credit_amount_may        0
# 31       debit_amount_jun        0
# 32      credit_amount_jun        0
# 33       credit_count_jun     1810
# 34        debit_count_jun        0
# 35  max_credit_amount_jun        0
# 36             emi_active        0

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)
X = pd.DataFrame(X, columns=X_cols)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=72)

# %%
def rmsle(actual_column, predicted_column):
    sum=0.0
    for x,y in zip(actual_column,predicted_column):
        if x<0 or y<0: #check for negative values. 
            continue
        p = np.log(y+1)
        r = np.log(x+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted_column))**0.5

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
Train_rmse=np.sqrt(mean_squared_error(y_train, lr.predict(X_train)))
Train_Test_rmse=np.sqrt(mean_squared_error(y_test, lr.predict(X_test)))
Train_rmse,Train_Test_rmse
print('Rmse Train data',Train_rmse)
print('Rmse Test data',Train_Test_rmse)
# Out:
# Rmse Train data 1.6077337546779327
# Rmse Test data 1.6152702838307542

# %%
print('RMSLE',rmsle(y_test,y_pred))
# Out:
# RMSLE 0.15997909173272234

# %% [markdown]
# # Test Data

# %%
Test_df=pd.read_csv('../Data/Test.csv')

# %%
Test_df.head()
# Out:
#       ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0  17591      current      M   37          575      2795.45       1290.0
# 1  13541      current      M   33          394     29405.13       1640.0
# 2  13431      current      M   53          324      5985.20       6189.0
# 3   8687      current      M   33          370      2105.93      18225.0
# 4  14727      current      M   62          505      3269.00       3532.0
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  ...  credit_count_may  \
# 0      6141.05       676.50      9146.10  ...              24.0
# 1      1670.00      2463.92     10947.50  ...              43.0
# 2      2696.09       766.00       716.00  ...              42.0
# 3     34763.56       167.00      4260.27  ...               3.0
# 4      3158.40      2699.77      3373.48  ...              70.0
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0             20.0                 9750.0          30527.88
# 1             40.0                16967.0          14342.83
# 2             35.0                36398.0          32503.16
# 3              5.0                97825.0          93572.42
# 4             75.0                27936.0          19011.50
#
#    credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0           31271.00               3.0             12.0
# 1           16582.00               6.0             39.0
# 2           33539.54               5.0              9.0
# 3          109429.75              21.0              0.0
# 4           41401.00               6.0             35.0
#
#    max_credit_amount_jun  loan_enq  emi_active
# 0               25945.92         Y     1170.49
# 1               12214.00         Y    16447.45
# 2               13215.00         Y     2622.28
# 3               72317.00         Y      340.79
# 4               42344.00         Y     2812.20
#
# [5 rows x 43 columns]

# %%
#check outliers of test data
check_outliers(Test_df)
# Out:
#                   columns Outliers
# 0                      ID        0
# 1                     age      172
# 2             region_code        0
# 3             cc_cons_apr      374
# 4             dc_cons_apr      369
# 5             cc_cons_may      378
# 6             dc_cons_may      396
# 7             cc_cons_jun      370
# 8             dc_cons_jun      468
# 9            cc_count_apr      283
# 10           cc_count_may      109
# 11           cc_count_jun       14
# 12           dc_count_apr       76
# 13           dc_count_may      428
# 14           dc_count_jun        0
# 15               card_lim       13
# 16   personal_loan_active        0
# 17    vehicle_loan_active        0
# 18   personal_loan_closed        0
# 19    vehicle_loan_closed        0
# 20           investment_1      662
# 21           investment_2      394
# 22           investment_3      519
# 23           investment_4      320
# 24       debit_amount_apr      331
# 25      credit_amount_apr      326
# 26        debit_count_apr       65
# 27       credit_count_apr       17
# 28  max_credit_amount_apr      374
# 29       debit_amount_may      379
# 30      credit_amount_may      323
# 31       credit_count_may      884
# 32        debit_count_may      210
# 33  max_credit_amount_may      408
# 34       debit_amount_jun      315
# 35      credit_amount_jun      336
# 36       credit_count_jun      591
# 37        debit_count_jun        0
# 38  max_credit_amount_jun      377
# 39             emi_active      441

# %%
Test_df[num_cols] = removing_outliers(Test_df[num_cols])
# Out:
# C:\Users\ruchita\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
check_outliers(Test_df)
# Out:
#                   columns Outliers
# 0                      ID        0
# 1                     age        0
# 2             region_code        0
# 3             cc_cons_apr        0
# 4             dc_cons_apr        0
# 5             cc_cons_may        0
# 6             dc_cons_may        0
# 7             cc_cons_jun        0
# 8             dc_cons_jun        0
# 9            cc_count_apr        0
# 10           cc_count_may        0
# 11           cc_count_jun        0
# 12           dc_count_apr        0
# 13           dc_count_may        0
# 14           dc_count_jun        0
# 15               card_lim        0
# 16   personal_loan_active        0
# 17    vehicle_loan_active        0
# 18   personal_loan_closed        0
# 19    vehicle_loan_closed        0
# 20           investment_1      662
# 21           investment_2        0
# 22           investment_3      519
# 23           investment_4        0
# 24       debit_amount_apr        0
# 25      credit_amount_apr        0
# 26        debit_count_apr        0
# 27       credit_count_apr        0
# 28  max_credit_amount_apr        0
# 29       debit_amount_may        0
# 30      credit_amount_may        0
# 31       credit_count_may      884
# 32        debit_count_may        0
# 33  max_credit_amount_may        0
# 34       debit_amount_jun        0
# 35      credit_amount_jun        0
# 36       credit_count_jun      591
# 37        debit_count_jun        0
# 38  max_credit_amount_jun        0
# 39             emi_active        0

# %%
Test_Id = Test_df['ID']

# %%
Test_df = Test_df.drop(['ID'],axis=1)

# %%
Test_df['account_type']=pd.get_dummies(Test_df['account_type'])

Test_df['gender']=pd.get_dummies(Test_df['gender'])

# %%
Test_df=Test_df.drop(['personal_loan_active','personal_loan_closed','vehicle_loan_active','vehicle_loan_closed','loan_enq'],axis=1)

# %%
Test_df_col = Test_df.columns

# %%
Test_df = scaler.transform(Test_df)
Test_df = pd.DataFrame(Test_df, columns=Test_df_col)

# %%
Test_df['cc_cons'] = lr.predict(Test_df)

# %%
Test_df['cc_cons'] = np.exp(Test_df['cc_cons'])-1

# %%
sub_lr = pd.concat([Test_Id, Test_df['cc_cons']], axis=1)

# %%
sub_lr.to_csv('sub_Lr.csv', index=False)

# %%
submissions_lr
# Out:
#          ID       cc_cons
# 0     17591  13532.214842
# 1     13541  15747.052028
# 2     13431  13402.686237
# 3      8687  15903.905753
# 4     14727  13668.601380
# 5     14988  14595.174742
# 6     14859  17238.501660
# 7     16636  15238.365072
# 8      7625  15006.549819
# 9     16492  14734.946002
# 10    13674  14522.727416
# 11    11981  18083.511457
# 12     5185  15249.501009
# 13    15288  13186.833765
# 14    18526  15086.141903
# 15    16760  16701.526141
# 16    10805  16286.437795
# 17     8830  13856.447514
# 18     8926  17127.446640
# 19    10974  17207.576927
# 20     2155  14533.331952
# 21    17251  14617.463145
# 22    12154  15158.960255
# 23    12227  15426.717919
# 24    19961  15784.789297
# 25    13866  16046.427916
# 26    17498  16933.455504
# 27     7241  15289.485547
# 28      414  15698.091480
# 29      206  15474.845213
# ...     ...           ...
# 4970   8723  15269.054241
# 4971  16532  17410.436602
# 4972  11859  16684.966557
# 4973   5390  14720.466064
# 4974    903  16181.385423
# 4975   8766  16334.513613
# 4976   3246  14628.167257
# 4977  16165  15763.503985
# 4978   5379  16792.582829
# 4979   6303  13481.463745
# 4980   6314  15344.892157
# 4981  19698  16027.016333
# 4982  15884  16063.870000
# 4983   6279  15092.485247
# 4984  12588  15575.832763
# 4985   8646  15307.436665
# 4986  16199  16666.745004
# 4987   3089  15536.804725
# 4988  12984  13725.229142
# 4989   7684  16959.572114
# 4990   3187  15911.044568
# 4991   5898  14015.582542
# 4992   9347  17445.300020
# 4993  14555  15389.411038
# 4994   9054  13784.750542
# 4995  12512  14563.644837
# 4996  14224  16279.084022
# 4997  18740  14504.036902
# 4998  18134  13190.718622
# 4999  12413  14855.185404
#
# [5000 rows x 2 columns]
